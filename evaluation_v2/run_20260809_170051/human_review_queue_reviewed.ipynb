# %% [markdown]
# # Load the human_review_queue file for manual revision

# %%
#load the csv file evaluation_v2\run_20260809_170051\human_review_queue_reviwed.xlsx into a pandas dataframe and print the first 5 rows
import pandas as pd
from pathlib import Path

ROOT = Path.cwd().resolve().parent.parent

review_path = (
    ROOT
    / "evaluation_v2"
    / "run_20260809_170051"
    / "human_review_queue.csv"
)

df = pd.read_csv(
    review_path,
    dtype={
        "human_covered_claims": "string",
        "human_decision": "string",
        "human_notes": "string",
        "adjudicator": "string",
        "adjudication_notes": "string",
    },
    keep_default_na=False,
)

df["human_grade"] = pd.to_numeric(
    df["human_grade"],
    errors="coerce"
).astype("Int64")

# %%
# mostrar el texto completo de todas las columnas del dataframe
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# # Review each row one by one

# %%
#print row 1 
df.iloc[[145]]
# Out:
#     review_id question_id  claim_id evidence_id  \
# 145    R00146        Q028  Q028-C01  Q028-E0028
#
#                                                                                         question  \
# 145  ¿Cuáles son las mutaciones genéticas más frecuentes en cáncer de mama y ovario hereditario?
#
#                                                                                                     claim_text  \
# 145  Mutations in BRCA1 and BRCA2 high penetrance genes account for most hereditary breast and ovarian cancer.
#
# ...

# %%
row = 0

df.at[row, "human_grade"] = 3
df.at[row, "human_covered_claims"] = "Q002-C01; Q002-C03"
df.at[row, "human_decision"] = "accept"
df.at[row, "human_notes"] = (
    "La evidencia respalda directamente y de forma completa el claim Q002-C01."
)

# %%
row = 1
df.at[row, "human_grade"] = 3
df.at[row, "human_covered_claims"] = "Q002-C01; Q002-C02; Q002-C03"
df.at[row, "human_decision"] = "accept"
df.at[row, "human_notes"] = (
    "La evidencia respalda el claim de manera completa"
)

# %%
row = 2
df.at[row, "human_grade"] = 3
df.at[row, "human_covered_claims"] = "Q002-C03; Q002-C04"
df.at[row, "human_decision"] = "accept"
df.at[row, "human_notes"] = (
    "La evidencia respalda el claim de manera completa"
)

# %%
row = 3
df.at[row, "human_grade"] = 3
df.at[row, "human_covered_claims"] = "Q002-C05; Q002-C03"
df.at[row, "human_decision"] = "accept"
df.at[row, "human_notes"] = (
    "La evidencia respalda el claim de manera completa"
)

# %%
row = 4
df.at[row, "human_grade"] = 3
df.at[row, "human_covered_claims"] = "Q005-C01"
df.at[row, "human_decision"] = "accept"
df.at[row, "human_notes"] = (
    "La evidencia respalda el claim de manera completa"
)

# %%
row = 5
df.at[row, "human_grade"] = 3
df.at[row, "human_covered_claims"] = "Q006-C01"
df.at[row, "human_decision"] = "accept"
df.at[row, "human_notes"] = (
    "La evidencia respalda el claim de manera completa"
)

# %%
row = 6
df.at[row, "human_grade"] = 3
df.at[row, "human_covered_claims"] = "Q008-C01; Q008-C02"
df.at[row, "human_decision"] = "accept"
df.at[row, "human_notes"] = (
    "La evidencia respalda el claim de manera completa"
)

# %%
row = 7
df.at[row, "human_grade"] = 3
df.at[row, "human_covered_claims"] = "Q008-C01; Q008-C02"
df.at[row, "human_decision"] = "accept"
df.at[row, "human_notes"] = (
    "La evidencia respalda el claim de manera completa"
)

# %%
row = 8
df.at[row, "human_grade"] = 0
#df.at[row, "human_covered_claims"] = 
df.at[row, "human_decision"] = "reject"

# %%
row = 9
df.at[row, "human_decision"] = "accept"
df.at[row, "human_notes"] = ("keep")

# %%
row = 10
df.at[row, "human_decision"] = "uncertain"
df.at[row, "human_notes"] = "rewrite to: Los principales efectos secundarios son: Anorexia, Artralgia, Caídas, Diarrea, Disminución de peso, Fatiga, Fracturas, Hipertensión, Sarpullido, Sofocos."

# %%
row = 11
df.at[row, "human_grade"] = 3
df.at[row, "human_covered_claims"] = "Q012-C01"
df.at[row, "human_decision"] = "accept"
df.at[row, "human_notes"] = (
    "La evidencia apoya el claim."
)

# %%
row = 12
df.at[row, "human_grade"] = 0
df.at[row, "human_decision"] = "reject"
df.at[row, "human_notes"] = (
    "La evidencia no respalda el claim. La combinación de radioterapia y TPA se presenta en el diagrama para cáncer de próstata localizado de riesgo intermedio, no para enfermedad localmente avanzada. El texto que menciona enfermedad localmente avanzada no confirma esa combinación terapéutica. Evidencia de ámbito clínico incorrecto."
)

# %%
row = 13
df.at[row, "human_grade"] = 0
df.at[row, "human_decision"] = "reject"
df.at[row, "human_notes"] = (
    "La evidencia no respalda el claim: no menciona recidiva tras prostatectomía ni radioterapia en la zona prostática. Además, el claim no responde directamente a la pregunta, que solicita tipos de cáncer tratados con terapia de privación de andrógenos. Marcar el claim para revisión de relevancia o retirada."
)

# %%
row = 14
df.at[row, "human_grade"] = 0
df.at[row, "human_decision"] = "uncertain"
df.at[row, "human_notes"] = (
    "La evidencia no respalda el claim"
)

# %%
row = 15
df.at[row, "human_grade"] = 0
df.at[row, "human_decision"] = "reject"
df.at[row, "human_notes"] = (
    "La evidencia no respalda el claim. Además la evidencia proviene de información sobre el cancer de mama y la pregunta es sobre cáncer de próstata"
)

# %%
row = 16
df.at[row, "human_grade"] = 0
df.at[row, "human_decision"] = "reject"
df.at[row, "human_notes"] = (
    "La evidencia no respalda el claim. Además la evidencia proviene de información sobre el cancer de mama y la pregunta es sobre cáncer de próstata"
)

# %%
row = 17
df.at[row, "human_grade"] = 2
df.at[row, "human_covered_claims"] = "Q013-C11"
df.at[row, "human_decision"] = "uncertain"
df.at[row, "human_notes"] = (
    "La evidencia soporta parcialmente el claim ya que el claim no especifica tipo de cancer (mama, próstata, etc.) mientras que la evidencia sí"
)

# %%
row = 18
df.at[row, "human_grade"] = 0
df.at[row, "human_decision"] = "reject"
df.at[row, "human_notes"] = (
    "La evidencia no soporta el claim"
)

# %%
row = 19
df.at[row, "human_grade"] = 3
df.at[row, "human_covered_claims"] = "Q013-C11"
df.at[row, "human_decision"] = "accept"
df.at[row, "human_notes"] = (
    "La evidencia soporta el claim"
)

# %%
row = 20
df.at[row, "human_grade"] = 3
df.at[row, "human_covered_claims"] = "Q014-C02"
df.at[row, "human_decision"] = "accept"
df.at[row, "human_notes"] = (
    "La evidencia soporta el claim"
)

# %%
row = 21
df.at[row, "human_grade"] = 3
df.at[row, "human_covered_claims"] = "Q014-C02"
df.at[row, "human_decision"] = "accept"
df.at[row, "human_notes"] = (
    "La evidencia soporta el claim"
)

# %%
row = 22
df.at[row, "human_grade"] = 1
df.at[row, "human_decision"] = "reject"
df.at[row, "human_notes"] = (
    "La evidencia es relacionada con la función sexual tras cirugía, pero no informa sobre la eyaculación. El claim “Problemas de erección” no responde directamente a la pregunta y debe revisarse o retirarse como claim requerido."
)

# %%
row = 23
df.at[row, "human_grade"] = 0
df.at[row, "human_decision"] = "reject"
df.at[row, "human_notes"] = (
    "La evidencia no apoya este claim. El claim “Problemas de erección” no responde directamente a la pregunta y debe revisarse o retirarse como claim requerido."
)

# %%
row = 24
df.at[row, "human_grade"] = 0
df.at[row, "human_decision"] = "reject"
df.at[row, "human_notes"] = (
    "La evidencia no apoya este claim. Además la pregunta solicita información sobre cáncer de próstata, mientras que la evidencia se refiere a cáncer de mama."
)

# %%
row = 25
df.at[row, "human_grade"] = 0
df.at[row, "human_decision"] = "reject"
df.at[row, "human_notes"] = (
    "La evidencia no apoya este claim. Además la pregunta solicita información sobre cáncer de próstata, mientras que la evidencia se refiere a cáncer de mama."
)

# %%
row = 26
df.at[row, "human_grade"] = 0
df.at[row, "human_decision"] = "reject"
df.at[row, "human_notes"] = (
    "La evidencia no apoya este claim."
)

# %%
row = 27
df.at[row, "human_grade"] = 0
df.at[row, "human_decision"] = "reject"
df.at[row, "human_notes"] = (
    "La evidencia no apoya este claim."
)

# %%
row = 28
df.at[row, "human_grade"] = 0
df.at[row, "human_decision"] = "reject"
df.at[row, "human_notes"] = (
    "La evidencia no apoya este claim."
)

# %%
row = 29
df.at[row, "human_grade"] = 0
df.at[row, "human_decision"] = "reject"
df.at[row, "human_notes"] = (
    "La evidencia no apoya este claim."
)

# %%
row = 30
df.at[row, "human_grade"] = 0
df.at[row, "human_decision"] = "reject"
df.at[row, "human_notes"] = (
    "La evidencia no apoya este claim."
)

# %%
row = 31
df.at[row, "human_grade"] = 1
df.at[row, "human_decision"] = "reject"
df.at[row, "human_notes"] = (
    "La evidencia no apoya este claim de manera directa. Menciona efectos secundarios pero no directamente la fertilidad."
)

# %%
row = 32
df.at[row, "human_grade"] = 3
df.at[row, "human_decision"] = "accept"
df.at[row, "human_covered_claims"] = "Q015-C10; Q015-C01"
df.at[row, "human_notes"] = (
    "La evidencia apoya este claim."
)

# %%
row = 33
df.at[row, "human_decision"] = "accept"
df.at[row, "human_notes"] = ("keep")

# %%
row = 34
df.at[row, "human_decision"] = "accept"
df.at[row, "human_notes"] = ("keep")

# %%
row = 35
df.at[row, "human_decision"] = "accept"
df.at[row, "human_notes"] = ("keep")

# %%
row = 36
df.at[row, "human_decision"] = "accept"
df.at[row, "human_notes"] = ("keep")

# %%
row = 37
df.at[row, "human_grade"] = 3
df.at[row, "human_decision"] = "accept"
df.at[row, "human_covered_claims"] = "Q016-C04"
df.at[row, "human_notes"] = (
    "La evidencia apoya este claim."
)

# %%
row = 38
df.at[row, "human_grade"] = 3
df.at[row, "human_decision"] = "accept"
df.at[row, "human_covered_claims"] = "Q016-C04"
df.at[row, "human_notes"] = (
    "La evidencia apoya este claim."
)

# %%
row = 39
df.at[row, "human_decision"] = "accept"
df.at[row, "human_notes"] = ("keep")

# %%
row = 40
df.at[row, "human_grade"] = 3
df.at[row, "human_decision"] = "accept"
df.at[row, "human_covered_claims"] = "Q016-C05"
df.at[row, "human_notes"] = (
    "La evidencia apoya este claim."
)

# %%
row = 41
df.at[row, "human_grade"] = 3
df.at[row, "human_decision"] = "accept"
df.at[row, "human_covered_claims"] = "Q016-C05"
df.at[row, "human_notes"] = (
    "La evidencia apoya este claim."
)

# %%
row = 42
df.at[row, "human_decision"] = "accept"
df.at[row, "human_notes"] = ("keep")

# %%
row = 43
df.at[row, "human_grade"] = 3
df.at[row, "human_decision"] = "accept"
df.at[row, "human_covered_claims"] = "Q016-C06"
df.at[row, "human_notes"] = (
    "La evidencia apoya este claim."
)

# %%
row = 44
df.at[row, "human_decision"] = "accept"
df.at[row, "human_notes"] = ("keep")

# %%
row = 45
df.at[row, "human_decision"] = "reject"
df.at[row, "human_notes"] = "rewrite to: Several studies have shown the prognostic value of ROR score in estimating risk of disease recurrence."

# %%
row = 46
df.at[row, "human_grade"] = 0
df.at[row, "human_decision"] = "reject"
df.at[row, "human_notes"] = (
    "La evidencia no apoya este claim."
)

# %%
row = 47
df.at[row, "human_grade"] = 0
df.at[row, "human_decision"] = "reject"
df.at[row, "human_notes"] = (
    "La evidencia no apoya este claim."
)

# %%
row = 48
df.at[row, "human_grade"] = 0
df.at[row, "human_decision"] = "reject"
df.at[row, "human_notes"] = (
    "La evidencia no apoya este claim."
)

# %%
row = 49
df.at[row, "human_grade"] = 0
df.at[row, "human_decision"] = "reject"
df.at[row, "human_notes"] = (
    "La evidencia no apoya este claim."
)

# %%
row = 50
df.at[row, "human_grade"] = 0
df.at[row, "human_decision"] = "reject"
df.at[row, "human_notes"] = (
    "La evidencia no apoya este claim."
)

# %%
row = 51
df.at[row, "human_grade"] = 0
df.at[row, "human_decision"] = "reject"
df.at[row, "human_notes"] = (
    "La evidencia no apoya este claim."
)

# %%
row = 52
df.at[row, "human_grade"] = 0
df.at[row, "human_decision"] = "reject"
df.at[row, "human_notes"] = (
    "La evidencia no apoya este claim."
)

# %%
row = 53
df.at[row, "human_grade"] = 0
df.at[row, "human_decision"] = "reject"
df.at[row, "human_notes"] = (
    "La evidencia no apoya este claim."
)

# %%
row = 54
df.at[row, "human_decision"] = "uncertain"
df.at[row, "human_notes"] = "rewrite to: Several studies have shown the prognostic value of ROR score in estimating risk of disease recurrence"

# %%
row = 55
df.at[row, "human_grade"] = 0
df.at[row, "human_decision"] = "reject"
df.at[row, "human_notes"] = (
    "La evidencia no apoya este claim."
)

# %%
row = 56
df.at[row, "human_grade"] = 0
df.at[row, "human_decision"] = "reject"
df.at[row, "human_notes"] = (
    "La evidencia no apoya este claim."
)

# %%
row = 57
df.at[row, "human_decision"] = "accept"
df.at[row, "human_notes"] = ("keep")

# %%
row = 58
df.at[row, "human_decision"] = "accept"
df.at[row, "human_notes"] = ("keep")

# %%
row = 59
df.at[row, "human_grade"] = 3
df.at[row, "human_decision"] = "accept"
df.at[row, "human_covered_claims"] = "Q018-C05"
df.at[row, "human_notes"] = (
    "La evidencia apoya este claim."
)

# %%
row = 60
df.at[row, "human_decision"] = "accept"
df.at[row, "human_notes"] = ("keep")

# %%
row = 61
df.at[row, "human_decision"] = "accept"
df.at[row, "human_notes"] = ("keep")

# %%
row = 62
df.at[row, "human_grade"] = 3
df.at[row, "human_decision"] = "accept"
df.at[row, "human_covered_claims"] = "Q019-C01"
df.at[row, "human_notes"] = (
    "La evidencia apoya este claim."
)

# %%
row = 63
df.at[row, "human_decision"] = "accept"
df.at[row, "human_notes"] = ("keep")

# %%
row = 64
df.at[row, "human_decision"] = "accept"
df.at[row, "human_notes"] = ("keep")

# %%
row = 65
df.at[row, "human_decision"] = "accept"
df.at[row, "human_notes"] = ("keep")

# %%
row = 66
df.at[row, "human_grade"] = 0
df.at[row, "human_decision"] = "reject"
df.at[row, "human_notes"] = (
    "La evidencia no apoya este claim."
)

# %%
row = 67
df.at[row, "human_grade"] = 2
df.at[row, "human_covered_claims"] = "Q019-C04"
df.at[row, "human_decision"] = "uncertain"
df.at[row, "human_notes"] = (
    "La evidencia apoya el claim pero no queda claro si responde del todo a la pregunta. Ya que la evidencia habla de terapias endocrinas en general y la pregunta es sobre los efectos secundarios del tamoxifeno"
)

# %%
row = 68
df.at[row, "human_grade"] = 0
df.at[row, "human_decision"] = "reject"
df.at[row, "human_notes"] = (
    "La evidencia no apoya este claim. La evidencia habla sobre otro tipo de terapias para el cancer de mama, no del tamoxifeno"
)

# %%
row = 69
df.at[row, "human_grade"] = 0
df.at[row, "human_decision"] = "reject"
df.at[row, "human_notes"] = (
    "La evidencia no apoya este claim. La evidencia habla sobre otro tipo de terapias para el cancer de mama, no del tamoxifeno"
)

# %%
row = 70
df.at[row, "human_grade"] = 0
df.at[row, "human_decision"] = "reject"
df.at[row, "human_notes"] = (
    "La evidencia no apoya este claim. La evidencia habla sobre otro tipo de terapias para el cancer de mama, no del tamoxifeno"
)

# %%
row = 71
df.at[row, "human_grade"] = 3
df.at[row, "human_covered_claims"] = "Q019-C04"
df.at[row, "human_decision"] = "accept"
df.at[row, "human_notes"] = (
    "La evidencia si apoya el claim."
)

# %%
row = 72
df.at[row, "human_decision"] = "accept"
df.at[row, "human_notes"] = ("rewrite to: Algunos efectos secundarios son: Aumento de la sudoración, Complicaciones tromboembólicas, Engrosamiento endometrial, Fatiga, Náuseas, Retención de líquidos, Sangrado/secreción vaginal, Sarpullido cutáneo, Sofocos y Trastornos visuales")

# %%
row = 73
df.at[row, "human_decision"] = "accept"
df.at[row, "human_notes"] = ("keep")

# %%
row = 74
df.at[row, "human_decision"] = "reject"
df.at[row, "human_notes"] = "reject. El claim está incompleto. "

# %%
row = 75
df.at[row, "human_decision"] = "accept"
df.at[row, "human_notes"] = ("keep")

# %%
row = 76
df.at[row, "human_decision"] = "accept"
df.at[row, "human_notes"] = ("keep")

# %%
row = 77
df.at[row, "human_decision"] = "accept"
df.at[row, "human_notes"] = ("keep")

# %%
row = 78
df.at[row, "human_decision"] = "accept"
df.at[row, "human_notes"] = ("keep")

# %%
row = 79
df.at[row, "human_decision"] = "accept"
df.at[row, "human_notes"] = ("keep")

# %%
row = 80
df.at[row, "human_decision"] = "accept"
df.at[row, "human_notes"] = ("keep")

# %%
row = 81
df.at[row, "human_decision"] = "accept"
df.at[row, "human_notes"] = ("keep")

# %%
row = 82
df.at[row, "human_decision"] = "accept"
df.at[row, "human_notes"] = ("keep")

# %%
row = 83
df.at[row, "human_grade"] = 3
df.at[row, "human_covered_claims"] = "Q020-C10"
df.at[row, "human_decision"] = "accept"
df.at[row, "human_notes"] = (
    "La evidencia si apoya el claim."
)

# %%
row = 84
df.at[row, "human_decision"] = "accept"
df.at[row, "human_notes"] = ("keep")

# %%
row = 85
df.at[row, "human_grade"] = 3
df.at[row, "human_covered_claims"] = "Q020-C11"
df.at[row, "human_decision"] = "accept"
df.at[row, "human_notes"] = (
    "La evidencia si apoya el claim."
)

# %%
row = 86
df.at[row, "human_decision"] = "accept"
df.at[row, "human_notes"] = ("keep")

# %%
row = 87
df.at[row, "human_decision"] = "accept"
df.at[row, "human_notes"] = ("keep")

# %%
row = 88
df.at[row, "human_decision"] = "accept"
df.at[row, "human_notes"] = ("keep")

# %%
row = 89
df.at[row, "human_grade"] = 3
df.at[row, "human_covered_claims"] = "Q020-C14"
df.at[row, "human_decision"] = "accept"
df.at[row, "human_notes"] = (
    "La evidencia si apoya el claim."
)

# %%
row = 90
df.at[row, "human_grade"] = 3
df.at[row, "human_covered_claims"] = "Q020-C14"
df.at[row, "human_decision"] = "accept"
df.at[row, "human_notes"] = (
    "La evidencia si apoya el claim."
)

# %%
row = 91
df.at[row, "human_grade"] = 3
df.at[row, "human_covered_claims"] = "Q020-C14"
df.at[row, "human_decision"] = "accept"
df.at[row, "human_notes"] = (
    "La evidencia si apoya el claim."
)

# %%
row = 92
df.at[row, "human_grade"] = 3
df.at[row, "human_covered_claims"] = "Q020-C14"
df.at[row, "human_decision"] = "accept"
df.at[row, "human_notes"] = (
    "La evidencia si apoya el claim."
)

# %%
row = 93
df.at[row, "human_grade"] = 1
df.at[row, "human_decision"] = "reject"
df.at[row, "human_notes"] = (
    "Aunque parece que la evidencia resplada el claim, la evidencia habla sobre cáncer de próstata y el tamoxifeno es un tratamiento para cáncer de mama."
)

# %%
row = 94
df.at[row, "human_decision"] = "accept"
df.at[row, "human_notes"] = ("keep")

# %%
row = 95
df.at[row, "human_grade"] = 0
df.at[row, "human_decision"] = "reject"
df.at[row, "human_notes"] = (
    "La evidencia no apoya este claim."
)

# %%
row = 96
df.at[row, "human_grade"] = 1
df.at[row, "human_decision"] = "reject"
df.at[row, "human_notes"] = (
    "Aunque la evidencia menciona los síntomas del claim, no se refieren a lo mismo."
)

# %%
row = 97
df.at[row, "human_decision"] = "accept"
df.at[row, "human_notes"] = "El claim aparece textualmente en mama_es_novartis_guia-pacientes-CM_2025.pdf"

# %%
row = 98
df.at[row, "human_grade"] = 3
df.at[row, "human_covered_claims"] = "Q021-C07"
df.at[row, "human_decision"] = "accept"
df.at[row, "human_notes"] = (
    "La evidencia si apoya el claim."
)

# %%
row = 99
df.at[row, "human_grade"] = 3
df.at[row, "human_covered_claims"] = "Q023-C01"
df.at[row, "human_decision"] = "accept"
df.at[row, "human_notes"] = (
    "La evidencia si apoya el claim."
)

# %%
row = 100
df.at[row, "human_grade"] = 3
df.at[row, "human_covered_claims"] = "Q023-C02"
df.at[row, "human_decision"] = "accept"
df.at[row, "human_notes"] = (
    "La evidencia si apoya el claim."
)

# %%
row = 101
df.at[row, "human_grade"] = 3
df.at[row, "human_covered_claims"] = "Q025-C01"
df.at[row, "human_decision"] = "accept"
df.at[row, "human_notes"] = (
    "La evidencia si apoya el claim."
)

# %%
row = 102
df.at[row, "human_grade"] = 3
df.at[row, "human_covered_claims"] = "Q025-C06"
df.at[row, "human_decision"] = "accept"
df.at[row, "human_notes"] = (
    "La evidencia si apoya el claim."
)

# %%
row = 103
df.at[row, "human_grade"] = 3
df.at[row, "human_covered_claims"] = "Q025-C08"
df.at[row, "human_decision"] = "accept"
df.at[row, "human_notes"] = (
    "La evidencia si apoya el claim."
)

# %%
row = 104
df.at[row, "human_decision"] = "accept"
df.at[row, "human_notes"] = ("keep")

# %%
row = 105
df.at[row, "human_decision"] = "uncertain"
df.at[row, "human_notes"] = "rewrite to: Existen varios factores de riesgo asociados al cáncer de mama, que pueden dividirse en factores de riesgo modificables o no modificables."

# %%
row = 106
df.at[row, "human_decision"] = "uncertain"
df.at[row, "human_notes"] = "rewrite to: La mayor parte de los factores de riesgo se relaciona con los antecedentes reproductivos que modulan la exposición hormonal durante la vida."

# %%
row = 107
df.at[row, "human_decision"] = "accept"
df.at[row, "human_notes"] = ("keep")

# %%
row = 108
df.at[row, "human_decision"] = "accept"
df.at[row, "human_notes"] = ("keep")

# %%
row = 109
df.at[row, "human_grade"] = 0
df.at[row, "human_decision"] = "reject"
df.at[row, "human_notes"] = (
    "La evidencia no apoya este claim."
)

# %%
row = 110
df.at[row, "human_grade"] = 1
df.at[row, "human_decision"] = "reject"
df.at[row, "human_notes"] = (
    "La evidencia menciona el mayor riesgo con la edad pero se refieren a cosas diferentes. El claim habla de los factores de riesgo para el cáncer de mama y la evidencia sobre la quimioterapia."
)

# %%
row = 111
df.at[row, "human_grade"] = 0
df.at[row, "human_decision"] = "reject"
df.at[row, "human_notes"] = (
    "La evidencia habla sobre cancér de próstata y el claim sobre cáncer de mama. No hay relación entre ambos.")

# %%
row = 112
df.at[row, "human_grade"] = 0
df.at[row, "human_decision"] = "reject"
df.at[row, "human_notes"] = (
    "La evidencia habla sobre cancér de próstata y el claim sobre cáncer de mama. No hay relación entre ambos.")

# %%
row = 113
df.at[row, "human_decision"] = "uncertain"
df.at[row, "human_notes"] = "rewrite to: La historia personal puede ser un factor de riesgo para padecer cáncer de mama. Por ejemplo, las mujeres que han tenido un cáncer de mama invasivo tienen más riesgo de padecer un cáncer de mama contralateral."

# %%
row = 114
df.at[row, "human_decision"] = "accept"
df.at[row, "human_notes"] = ("keep")

# %%
row = 115
df.at[row, "human_decision"] = "accept"
df.at[row, "human_notes"] = ("keep")

# %%
row = 116
df.at[row, "human_decision"] = "accept"
df.at[row, "human_notes"] = ("keep")

# %%
row = 117
df.at[row, "human_decision"] = "accept"
df.at[row, "human_notes"] = ("keep")

# %%
row = 118
df.at[row, "human_decision"] = "reject"
df.at[row, "human_notes"] = "reject"

# %%
row = 119
df.at[row, "human_decision"] = "accept"
df.at[row, "human_notes"] = ("keep")

# %%
row = 120
df.at[row, "human_decision"] = "accept"
df.at[row, "human_notes"] = ("keep")

# %%
row = 121
df.at[row, "human_decision"] = "uncertain"
df.at[row, "human_notes"] = ("rewrite to: El consumo de alcohol es un factor de riesgo para el cáncer de mama.")

# %%
row = 122
df.at[row, "human_decision"] = "accept"
df.at[row, "human_notes"] = ("keep")

# %%
row = 123
df.at[row, "human_decision"] = "uncertain"
df.at[row, "human_notes"] = ("rewrite to: El sedentarismo es un factor de riesgo para el cáncer de mama.")

# %%
row = 124
df.at[row, "human_decision"] = "accept"
df.at[row, "human_notes"] = ("keep")

# %%
row = 125
df.at[row, "human_decision"] = "accept"
df.at[row, "human_notes"] = ("keep")

# %%
row = 126
df.at[row, "human_decision"] = "accept"
df.at[row, "human_notes"] = ("keep")

# %%
row = 127
df.at[row, "human_decision"] = "accept"
df.at[row, "human_notes"] = ("keep")

# %%
row = 128
df.at[row, "human_decision"] = "uncertain"
df.at[row, "human_notes"] = ("rewrite to: El género femenino es un factor de riesgo para el cáncer de mama.")

# %%
row = 129
df.at[row, "human_decision"] = "uncertain"
df.at[row, "human_notes"] = ("rewrite to: La edad avanzada es un factor de riesgo para el cáncer de mama.")

# %%
row = 130
df.at[row, "human_grade"] = 0
df.at[row, "human_decision"] = "reject"
df.at[row, "human_notes"] = (
    "El claim habla sobre un factor de riesgo del cáncer de mama y la evidencia sobre la teleasistencia.")

# %%
row = 131
df.at[row, "human_decision"] = "accept"
df.at[row, "human_notes"] = ("keep")

# %%
row = 132
df.at[row, "human_decision"] = "accept"
df.at[row, "human_notes"] = ("keep")

# %%
row = 133
df.at[row, "human_decision"] = "accept"
df.at[row, "human_notes"] = ("keep")

# %%
row = 134
df.at[row, "human_decision"] = "accept"
df.at[row, "human_notes"] = ("keep")

# %%
row = 135
df.at[row, "human_decision"] = "accept"
df.at[row, "human_notes"] = ("keep")

# %%
row = 136
df.at[row, "human_decision"] = "accept"

# %%
row = 137
df.at[row, "human_decision"] = "uncertain"
df.at[row, "human_notes"] = ("rewrite to: La obesidad es un factor de riesgo para el cáncer de mama.")

# %%
row = 138
df.at[row, "human_decision"] = "accept"

# %%
row = 139
df.at[row, "human_decision"] = "uncertain"
df.at[row, "human_notes"] = ("rewrite to: El alcohol es un factor de riesgo para el cáncer de mama.")

# %%
row = 140
df.at[row, "human_decision"] = "accept"
df.at[row, "human_notes"] = ("keep")

# %%
row = 141
df.at[row, "human_decision"] = "accept"
df.at[row, "human_notes"] = ("keep")

# %%
row = 142
df.at[row, "human_decision"] = "reject"
df.at[row, "human_notes"] = ("reject. El claim no responde a la pregunta")

# %%
row = 143
df.at[row, "human_grade"] = 0
df.at[row, "human_decision"] = "reject"
df.at[row, "human_notes"] = (
    "La evidencia no soporta el claim.")

# %%
row = 144
df.at[row, "human_decision"] = "accept"
df.at[row, "human_notes"] = ("keep")

# %%
row = 145
df.at[row, "human_grade"] = 2
df.at[row, "human_covered_claims"] = "Q028-C01"
df.at[row, "human_decision"] = "uncertain"
df.at[row, "human_notes"] = (
    "La evidencia es inconclusa. Hace falta revisarla")

# %%
row = 146
df.at[row, "human_grade"] = 0
df.at[row, "human_decision"] = "reject"
df.at[row, "human_notes"] = (
    "La evidencia no soporta el claim.")

# %%
row = 147
df.at[row, "human_grade"] = 0
df.at[row, "human_decision"] = "reject"
df.at[row, "human_notes"] = (
    "La evidencia no soporta el claim. La evidencia habla sobre cáncer de próstata y el claim sobre cáncer de mama. No hay relación entre ambos.")

# %%
row = 148
df.at[row, "human_decision"] = "accept"
df.at[row, "human_notes"] = ("keep")

# %%
row = 149
df.at[row, "human_decision"] = "accept"
df.at[row, "human_notes"] = ("keep")

# %%
row = 150
df.at[row, "human_decision"] = "accept"
df.at[row, "human_notes"] = ("keep")

# %%
row = 151
df.at[row, "human_grade"] = 3
df.at[row, "human_covered_claims"] = "Q028-C04"
df.at[row, "human_decision"] = "accept"
df.at[row, "human_notes"] = (
    "La evidencia si apoya el claim."
)

# %%
row = 152
df.at[row, "human_grade"] = 3
df.at[row, "human_covered_claims"] = "Q028-C04"
df.at[row, "human_decision"] = "accept"
df.at[row, "human_notes"] = (
    "La evidencia si apoya el claim."
)

# %%
row = 153
df.at[row, "human_decision"] = "accept"
df.at[row, "human_notes"] = ("keep")

# %%
row = 154
df.at[row, "human_grade"] = 2
df.at[row, "human_covered_claims"] = "Q028-C05"
df.at[row, "human_decision"] = "accept"
df.at[row, "human_notes"] = (
    "Soporta el claim de manera parcial."
)

# %%
row = 155
df.at[row, "human_decision"] = "accept"
df.at[row, "human_notes"] = ("keep")

# %%
row = 156
df.at[row, "human_decision"] = "accept"
df.at[row, "human_notes"] = ("keep")

# %%
row = 157
df.at[row, "human_decision"] = "accept"
df.at[row, "human_notes"] = ("keep")

# %%
row = 158
df.at[row, "human_decision"] = "accept"
df.at[row, "human_notes"] = ("keep")

# %%
row = 159
df.at[row, "human_decision"] = "accept"
df.at[row, "human_notes"] = ("keep")

# %%
row = 160
df.at[row, "human_grade"] = 3
df.at[row, "human_covered_claims"] = "Q028-C10"
df.at[row, "human_decision"] = "accept"
df.at[row, "human_notes"] = (
    "La evidencia soporta el claim."
)

# %%
row = 161
df.at[row, "human_grade"] = 3
df.at[row, "human_covered_claims"] = "Q028-C10"
df.at[row, "human_decision"] = "accept"
df.at[row, "human_notes"] = (
    "La evidencia soporta el claim."
)

# %%
row = 162
df.at[row, "human_decision"] = "accept"
df.at[row, "human_notes"] = ("keep")

# %%
row = 163
df.at[row, "human_grade"] = 3
df.at[row, "human_covered_claims"] = "Q028-C11"
df.at[row, "human_decision"] = "accept"
df.at[row, "human_notes"] = (
    "La evidencia soporta el claim."
)

# %%
row = 164
df.at[row, "human_grade"] = 3
df.at[row, "human_covered_claims"] = "Q030-C03"
df.at[row, "human_decision"] = "accept"
df.at[row, "human_notes"] = (
    "La evidencia soporta el claim."
)

# %%
row = 165
df.at[row, "human_grade"] = 3
df.at[row, "human_covered_claims"] = "Q031-C02"
df.at[row, "human_decision"] = "accept"
df.at[row, "human_notes"] = (
    "La evidencia soporta el claim."
)

# %%
df.iloc[[165]]

#mostrar las filas que tienen en la columna issue_type el valor "claim_segmentation_review"

df[df["claim_id"] == "Q015-C10"]
# Out:
#    review_id question_id  claim_id evidence_id  \
# 32    R00033        Q015  Q015-C10  Q015-E0086
#
#                                                     question  \
# 32  ¿Cómo afecta la prostatectomía radical a la eyaculación?
#
#                                                                                                                                                                                                                                                        claim_text  \
# 32  Las complicaciones más frecuentes de este tipo de cirugía son la incontinencia urinaria y la disfunción eréctil, que suelen aparecer inmediatamente después de la cirugía con opción de mejorar con el paso del tiempo (unos 12 y 18 meses, respectivamente).
#
# ...

# %% [markdown]
# # Save dataframe reviewed

# %%
#Save the dataframe to a new csv file
output_path = (
    ROOT
    / "evaluation_v2"
    / "run_20260809_170051"
    / "human_review_queue_reviewed.csv"
)

df.to_csv(output_path, index=False)

# %%
#load again the file to check that it was saved correctly
df_check = pd.read_csv(
    output_path,
    dtype={
        "human_covered_claims": "string",
        "human_decision": "string",
        "human_notes": "string",
        "adjudicator": "string",
        "adjudication_notes": "string",
    },
    keep_default_na=False,
)
